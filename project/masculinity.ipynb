# %% [markdown]
# <a href="https://colab.research.google.com/github/fraserrbarclay/Python-Data-Practicals/blob/main/project/masculinity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring data sets
# ---
#
# This [link](https://docs.google.com/document/d/1cijDOCDixsYu-Rr9pC8STPPXado3xoFpgBAZgdDTLHs/edit?usp=sharing) will take you to a list of some of the datasets we use during the Programming for Data course.
#
# For this exercise, please choose a dataset to work with.

# %% [markdown]
# Use the code cell below to play with the data.  Look at what data is included, where there is any null data, if there are any columns that need renaming, removing, new values calculated from them.
#
# Form some ideas of what you might want to know from the data and use the techniques you have learned so far to show the answers to these.  You might do this by getting summary statistics, by sorting and showing parts of the dataset, by calculating new values, etc.

# %% [markdown]
# ### What to do
# ---
#
# Decide what you want to know, explain this in the TEXT cell below, then write some code to get the answer.  When you have done this, add a new text cell below the code cell, explain what you have found.  Then do the same again, adding text cell, code cell, text cell, for something else you would like to know.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/fraserrbarclay/Python-Data-Practicals/raw/main/data/raw-responses.csv')

# %%
for column in ['Unnamed: 0','StartDate','EndDate']:
  del df[column]

# %%
new_names=['How "manly" do you feel?',
       "Is it important that people think you're manly",
       'Manly ideas from Father?', 'Manly ideas from Mother?',
       'Manly ideas from another member of family?',
       'Manly ideas from Pop Culture?', 'Manly ideas from Friends?',
       'Manly ideas from Other?', 'Does socety put pressure on men?',
       'often ask friend for professional advice?',
       'often ask a friend for personal advice?', 'often hug males?',
       'often cry?', 'often get into physical fights?',
       'often sexual with women?', 'often sexual with men?',
       'often watch sports?', 'often work out?', 'often therapy?',
       'often feel lonely?', 'worry:height?', 'worry:weight?', 'worry:hair?',
       'worry:physique', 'worry:genitals', 'worry:clothing', 'worry:sex?',
       'worry:mental health?', 'worry:physical health?', 'worry:finances?',
       'worry:family', 'worry:none of above?', 'how employed?',
       'work:make more money?', 'work:taken more seriously?',
       'work:have more choice?', 'work: male promotion preference',
       'work:praise', 'work:manager support', 'work:other advantages',
       'work:no advantages', 'work:female promotion opportunities',
       'work:sexual harassment', 'work:sexist/racist accusations',
       'work:other disadvantages', 'work:no disadvantages',
       'harassment: confront accussed', 'harassment:contact HR',
       'harassment:contact manager', 'harassment:offer victim support',
       'harassment:did not respond', 'harassment:never witnessed',
       'harassment: other response',
       'harassment:followup- why not respond at all', 'Knowledge of #MeToo',
       '#MeToo:Changed your behaviour at work', 'Dating: First Move?',
       'Dating: Do you pay?', 'Dating: Paying is the right thing to do',
       'Dating:I make more money than my date', 'Dating: Paying feels good',
       'Dating:Society expects me to pay', 'Dating: I asked; I pay',
       "Dating: I offer but I'm hoping they'll chip in",
       'Dating: Other reason to pay',
       'sex: read body language to gaugue interest',
       'sex: ask for verbal consent', 'sex:make a move and see how they react',
       'sex: depends on the context', 'sex:interest isnt always clear',
       'sex: other way to tell', 'boundaries:wondered if you crossed them?',
       'boundaries:talked to friend about pushing partner',
       'boundaries:asked if you crossed them?',
       'boundaries: did not wonder or ask',
       '#MeeToo:Changed behaviour in relationships', 'Married?',
       'u18 children?', 'adult children', 'no children', 'sex pref', 'race',
       'education level', 'state', 'salary', 'region', 'device', 'race2',
       'race3', 'education2', 'education3', 'age', 'kids', 'sex pref 2',
       'weight']

# %%
for i in range(0,len(df.columns)):
  df.rename(columns={df.columns[i]:new_names[i]}, inplace=True)

# %%
df
# Out:
#      How "manly" do you feel? Is it important that people think you're manly  \
# 0          Somewhat masculine                             Somewhat important
# 1          Somewhat masculine                             Somewhat important
# 2              Very masculine                              Not too important
# 3              Very masculine                              Not too important
# 4              Very masculine                                 Very important
# ...                       ...                                            ...
# 1610       Not very masculine                           Not at all important
# 1611           Very masculine                                 Very important
# 1612       Somewhat masculine                             Somewhat important
# 1613       Somewhat masculine                             Somewhat important
# 1614           Very masculine                           Not at all important
#
#         Manly ideas from Father?    Manly ideas from Mother?  \
# 0                   Not selected                Not selected
# 1     Father or father figure(s)                Not selected
# 2     Father or father figure(s)                Not selected
# 3     Father or father figure(s)  Mother or mother figure(s)
# 4                   Not selected                Not selected
# ...                          ...                         ...
# 1610  Father or father figure(s)  Mother or mother figure(s)
# 1611  Father or father figure(s)                Not selected
# 1612                Not selected  Mother or mother figure(s)
# 1613                Not selected  Mother or mother figure(s)
# 1614  Father or father figure(s)  Mother or mother figure(s)
#
#      Manly ideas from another member of family? Manly ideas from Pop Culture?  \
# 0                                  Not selected                   Pop culture
# 1                                  Not selected                  Not selected
# 2                                  Not selected                  Not selected
# 3                          Other family members                  Not selected
# 4                          Other family members                  Not selected
# ...                                         ...                           ...
# 1610                       Other family members                   Pop culture
# 1611                       Other family members                  Not selected
# 1612                               Not selected                  Not selected
# 1613                               Not selected                  Not selected
# 1614                               Not selected                  Not selected
#
#      Manly ideas from Friends? Manly ideas from Other?  \
# 0                 Not selected            Not selected
# 1                 Not selected            Not selected
# 2                 Not selected  Other (please specify)
# 3                 Not selected            Not selected
# 4                 Not selected            Not selected
# ...                        ...                     ...
# 1610                   Friends            Not selected
# 1611              Not selected            Not selected
# 1612              Not selected            Not selected
# 1613              Not selected            Not selected
# 1614              Not selected            Not selected
#
#      Does socety put pressure on men?  \
# 0                                 Yes
# 1                                 Yes
# 2                                  No
# 3                                  No
# 4                                 Yes
# ...                               ...
# 1610                              Yes
# 1611                              Yes
# 1612                              Yes
# 1613                              Yes
# 1614                               No
#
#      often ask friend for professional advice?  ...              region  \
# 0                                        Often  ...     Middle Atlantic
# 1                                       Rarely  ...  East North Central
# 2                                    Sometimes  ...  East North Central
# 3                                       Rarely  ...  East North Central
# 4                                    Sometimes  ...  East North Central
# ...                                        ...  ...                 ...
# 1610                                    Rarely  ...  West North Central
# 1611                                     Often  ...                 NaN
# 1612                                 No answer  ...      South Atlantic
# 1613                                 Sometimes  ...            Mountain
# 1614                                     Often  ...     Middle Atlantic
#
#                         device      race2     race3           education2  \
# 0     Windows Desktop / Laptop  Non-white  Hispanic      College or more
# 1           iOS Phone / Tablet      White     White         Some college
# 2     Windows Desktop / Laptop      White     White      College or more
# 3     Windows Desktop / Laptop      White     White         Some college
# 4     Windows Desktop / Laptop      White     White      College or more
# ...                        ...        ...       ...                  ...
# 1610        iOS Phone / Tablet      White     White         Some college
# 1611        iOS Phone / Tablet  Non-white  Hispanic  High school or less
# 1612  Windows Desktop / Laptop      White     White         Some college
# 1613  Windows Desktop / Laptop      White     White  High school or less
# 1614        iOS Phone / Tablet      White     White         Some college
#
#                education3        age          kids    sex pref 2    weight
# 0         College or more    35 - 64   No children  Gay/Bisexual  1.714026
# 1            Some college  65 and up  Has children      Straight  1.247120
# 2         College or more    35 - 64  Has children      Straight  0.515746
# 3            Some college  65 and up  Has children     No answer  0.600640
# 4         College or more    35 - 64   No children      Straight  1.033400
# ...                   ...        ...           ...           ...       ...
# 1610         Some college    18 - 34   No children      Straight  2.891038
# 1611  High school or less    35 - 64  Has children      Straight  8.643674
# 1612         Some college    35 - 64  Has children      Straight  2.340241
# 1613  High school or less    18 - 34   No children      Straight  6.557984
# 1614         Some college    18 - 34   No children      Straight  2.817560
#
# [1615 rows x 95 columns]

# %%
df['how employed?'].unique()
# Out:
# array(['Not employed, NOT looking for work', 'Not employed-retired',
#        'Employed, working full-time', 'Not employed, student',
#        'Employed, working part-time', 'Not employed, looking for work',
#        'No answer'], dtype=object)

# %%
df['harassment:followup- why not respond at all'].unique()
# Out:
# array([nan, 'You weren?t sure it was sexual harassment',
#        'You didn?t want to get involved', 'Other (please specify)',
#        'No answer', 'You didn?t think it was your place',
#        'You weren?t sure who to contact'], dtype=object)

# %%
df['Married?'].unique()
# Out:
# array(['Never married', 'Widowed', 'Married', 'Divorced', 'Separated',
#        'No answer'], dtype=object)

# %%
df['sex pref'].unique()
# Out:
# array(['Gay', 'Straight', 'No answer', 'Bisexual', 'Other'], dtype=object)

# %%
df['sex pref 2'].unique()
# Out:
# array(['Gay/Bisexual', 'Straight', 'No answer', 'Other'], dtype=object)

# %%
df['race'].unique()
# Out:
# array(['Hispanic', 'White', 'Other', 'Black', 'Asian'], dtype=object)

# %%
df['race2'].unique()
# Out:
# array(['Non-white', 'White'], dtype=object)

# %%
df['race3'].unique()
# Out:
# array(['Hispanic', 'White', 'Other', 'Black'], dtype=object)

# %%
df['education level'].unique()
# Out:
# array(['College graduate', 'Some college', 'Post graduate degree',
#        'High school or G.E.D.', 'Did not complete high school',
#        "Associate's degree"], dtype=object)

# %%
df['education2'].unique()
# Out:
# array(['College or more', 'Some college', 'High school or less'],
#       dtype=object)

# %%
df['education3'].unique()
# Out:
# array(['College or more', 'Some college', 'Post graduate degree',
#        'High school or less'], dtype=object)

# %%
len(df['state'].unique())
# Out:
# 51

# %%
df['region'].unique()
# Out:
# array(['Middle Atlantic', 'East North Central', 'West North Central',
#        'Pacific', 'South Atlantic', nan, 'New England', 'Mountain',
#        'West South Central', 'East South Central'], dtype=object)

# %%
df['salary'].unique()
# Out:
# array(['$0-$9,999', '$50,000-$74,999', '$200,000+', '$25,000-$49,999',
#        '$150,000-$174,999', '$100,000-$124,999', '$125,000-$149,999',
#        '$10,000-$24,999', 'Prefer not to answer', '$75,000-$99,999',
#        '$175,000-$199,999', nan], dtype=object)

# %%
df['age'].unique()
# Out:
# array(['35 - 64', '65 and up', '18 - 34'], dtype=object)

# %%
df['device'].unique()
# Out:
# array(['Windows Desktop / Laptop', 'iOS Phone / Tablet', 'Other',
#        'MacOS Desktop / Laptop', 'Android Phone / Tablet', nan],
#       dtype=object)

# %%
def split_column(df,column,q_intro):
    for response in df[column].unique():
      response_column = f"{q_intro}:{response}"
      df[response_column] = 'No answer'
      df.insert(df.columns.get_loc(column), response_column, df.pop(response_column))

# Iterate through the rows and update 'Yes' for matching response columns
    for index, row in df.iterrows():
      response = row[column]
      response_column_name = f"{q_intro}:{response}"
      df.at[index, response_column_name] = 'Yes'

    df.drop(columns=[column], inplace=True)
    empty_column = f"{q_intro}:nan"
    if empty_column in df:
      df.drop(columns=[empty_column], inplace=True)
    return df

# %%
import numpy as np

def remove_missing(df) :
  for i in range (len(df.columns)):
    df.loc[df.iloc[:, i] == 'Not selected', df.columns[i]] = np.nan
    df.loc[df.iloc[:, i] == 'No answer', df.columns[i]] = np.nan
  return df
remove_missing(df)
# Out:
#      How "manly" do you feel? Is it important that people think you're manly  \
# 0          Somewhat masculine                             Somewhat important
# 1          Somewhat masculine                             Somewhat important
# 2              Very masculine                              Not too important
# 3              Very masculine                              Not too important
# 4              Very masculine                                 Very important
# ...                       ...                                            ...
# 1610       Not very masculine                           Not at all important
# 1611           Very masculine                                 Very important
# 1612       Somewhat masculine                             Somewhat important
# 1613       Somewhat masculine                             Somewhat important
# 1614           Very masculine                           Not at all important
#
#         Manly ideas from Father?    Manly ideas from Mother?  \
# 0                            NaN                         NaN
# 1     Father or father figure(s)                         NaN
# 2     Father or father figure(s)                         NaN
# 3     Father or father figure(s)  Mother or mother figure(s)
# 4                            NaN                         NaN
# ...                          ...                         ...
# 1610  Father or father figure(s)  Mother or mother figure(s)
# 1611  Father or father figure(s)                         NaN
# 1612                         NaN  Mother or mother figure(s)
# 1613                         NaN  Mother or mother figure(s)
# 1614  Father or father figure(s)  Mother or mother figure(s)
#
#      Manly ideas from another member of family? Manly ideas from Pop Culture?  \
# 0                                           NaN                   Pop culture
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3                          Other family members                           NaN
# 4                          Other family members                           NaN
# ...                                         ...                           ...
# 1610                       Other family members                   Pop culture
# 1611                       Other family members                           NaN
# 1612                                        NaN                           NaN
# 1613                                        NaN                           NaN
# 1614                                        NaN                           NaN
#
#      Manly ideas from Friends? Manly ideas from Other?  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN  Other (please specify)
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 1610                   Friends                     NaN
# 1611                       NaN                     NaN
# 1612                       NaN                     NaN
# 1613                       NaN                     NaN
# 1614                       NaN                     NaN
#
#      Does socety put pressure on men?  \
# 0                                 Yes
# 1                                 Yes
# 2                                  No
# 3                                  No
# 4                                 Yes
# ...                               ...
# 1610                              Yes
# 1611                              Yes
# 1612                              Yes
# 1613                              Yes
# 1614                               No
#
#      often ask friend for professional advice?  ...              region  \
# 0                                        Often  ...     Middle Atlantic
# 1                                       Rarely  ...  East North Central
# 2                                    Sometimes  ...  East North Central
# 3                                       Rarely  ...  East North Central
# 4                                    Sometimes  ...  East North Central
# ...                                        ...  ...                 ...
# 1610                                    Rarely  ...  West North Central
# 1611                                     Often  ...                 NaN
# 1612                                       NaN  ...      South Atlantic
# 1613                                 Sometimes  ...            Mountain
# 1614                                     Often  ...     Middle Atlantic
#
#                         device      race2     race3           education2  \
# 0     Windows Desktop / Laptop  Non-white  Hispanic      College or more
# 1           iOS Phone / Tablet      White     White         Some college
# 2     Windows Desktop / Laptop      White     White      College or more
# 3     Windows Desktop / Laptop      White     White         Some college
# 4     Windows Desktop / Laptop      White     White      College or more
# ...                        ...        ...       ...                  ...
# 1610        iOS Phone / Tablet      White     White         Some college
# 1611        iOS Phone / Tablet  Non-white  Hispanic  High school or less
# 1612  Windows Desktop / Laptop      White     White         Some college
# 1613  Windows Desktop / Laptop      White     White  High school or less
# 1614        iOS Phone / Tablet      White     White         Some college
#
#                education3        age          kids    sex pref 2    weight
# 0         College or more    35 - 64   No children  Gay/Bisexual  1.714026
# 1            Some college  65 and up  Has children      Straight  1.247120
# 2         College or more    35 - 64  Has children      Straight  0.515746
# 3            Some college  65 and up  Has children           NaN  0.600640
# 4         College or more    35 - 64   No children      Straight  1.033400
# ...                   ...        ...           ...           ...       ...
# 1610         Some college    18 - 34   No children      Straight  2.891038
# 1611  High school or less    35 - 64  Has children      Straight  8.643674
# 1612         Some college    35 - 64  Has children      Straight  2.340241
# 1613  High school or less    18 - 34   No children      Straight  6.557984
# 1614         Some college    18 - 34   No children      Straight  2.817560
#
# [1615 rows x 95 columns]

# %%
df = split_column(df,'how employed?','employment')

# %%
df = split_column(df,'Married?','marital status')

# %%
df = split_column(df,'harassment:followup- why not respond at all','harassment followup')

# %%
df = split_column(df,'sex pref 2', 'sexpref')

# %%
df = split_column(df,'race','race')

# %%
df = split_column(df,'education2','ed')

# %%
df = split_column(df,'age','age')

# %%
df = df.drop(columns=['no children','sex pref','region', 'education level','race2','race3','device','education3','kids'])

# %%
df.columns
# Out:
# Index(['How "manly" do you feel?',
#        'Is it important that people think you're manly',
#        'Manly ideas from Father?', 'Manly ideas from Mother?',
#        'Manly ideas from another member of family?',
#        'Manly ideas from Pop Culture?', 'Manly ideas from Friends?',
#        'Manly ideas from Other?', 'Does socety put pressure on men?',
#        'often ask friend for professional advice?',
#        ...
#        'ed:College or more', 'ed:Some college', 'ed:High school or less',
#        'age:35 - 64', 'age:65 and up', 'age:18 - 34', 'sexpref:Gay/Bisexual',
#        'sexpref:Straight', 'sexpref:Other', 'weight'],
#       dtype='object', length=104)

# %%
def normalise_yn(df) :
  for i in range (len(df.columns)):
    df.loc[df.iloc[:, i] == 'Yes', df.columns[i]] = 1
    df.loc[df.iloc[:, i] == 'No', df.columns[i]] = 0
    df.loc[df.iloc[:, i] == 'Often', df.columns[i]] = 4
    df.loc[df.iloc[:, i] == 'Sometimes', df.columns[i]] = 3
    df.loc[df.iloc[:, i] == 'Rarely', df.columns[i]] = 2
    df.loc[df.iloc[:, i] == 'Never, but open to it', df.columns[i]] = 1
    df.loc[df.iloc[:, i] == 'Never, and not open to it', df.columns[i]] =0
  return df
normalise_yn(df)
# Out:
#      How "manly" do you feel? Is it important that people think you're manly  \
# 0          Somewhat masculine                             Somewhat important
# 1          Somewhat masculine                             Somewhat important
# 2              Very masculine                              Not too important
# 3              Very masculine                              Not too important
# 4              Very masculine                                 Very important
# ...                       ...                                            ...
# 1610       Not very masculine                           Not at all important
# 1611           Very masculine                                 Very important
# 1612       Somewhat masculine                             Somewhat important
# 1613       Somewhat masculine                             Somewhat important
# 1614           Very masculine                           Not at all important
#
#         Manly ideas from Father?    Manly ideas from Mother?  \
# 0                            NaN                         NaN
# 1     Father or father figure(s)                         NaN
# 2     Father or father figure(s)                         NaN
# 3     Father or father figure(s)  Mother or mother figure(s)
# 4                            NaN                         NaN
# ...                          ...                         ...
# 1610  Father or father figure(s)  Mother or mother figure(s)
# 1611  Father or father figure(s)                         NaN
# 1612                         NaN  Mother or mother figure(s)
# 1613                         NaN  Mother or mother figure(s)
# 1614  Father or father figure(s)  Mother or mother figure(s)
#
#      Manly ideas from another member of family? Manly ideas from Pop Culture?  \
# 0                                           NaN                   Pop culture
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3                          Other family members                           NaN
# 4                          Other family members                           NaN
# ...                                         ...                           ...
# 1610                       Other family members                   Pop culture
# 1611                       Other family members                           NaN
# 1612                                        NaN                           NaN
# 1613                                        NaN                           NaN
# 1614                                        NaN                           NaN
#
#      Manly ideas from Friends? Manly ideas from Other?  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN  Other (please specify)
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 1610                   Friends                     NaN
# 1611                       NaN                     NaN
# 1612                       NaN                     NaN
# 1613                       NaN                     NaN
# 1614                       NaN                     NaN
#
#      Does socety put pressure on men?  \
# 0                                   1
# 1                                   1
# 2                                   0
# 3                                   0
# 4                                   1
# ...                               ...
# 1610                                1
# 1611                                1
# 1612                                1
# 1613                                1
# 1614                                0
#
#      often ask friend for professional advice?  ... ed:College or more  \
# 0                                            4  ...                  1
# 1                                            2  ...          No answer
# 2                                            3  ...                  1
# 3                                            2  ...          No answer
# 4                                            3  ...                  1
# ...                                        ...  ...                ...
# 1610                                         2  ...          No answer
# 1611                                         4  ...          No answer
# 1612                                       NaN  ...          No answer
# 1613                                         3  ...          No answer
# 1614                                         4  ...          No answer
#
#      ed:Some college ed:High school or less age:35 - 64 age:65 and up  \
# 0          No answer              No answer           1     No answer
# 1                  1              No answer   No answer             1
# 2          No answer              No answer           1     No answer
# 3                  1              No answer   No answer             1
# 4          No answer              No answer           1     No answer
# ...              ...                    ...         ...           ...
# 1610               1              No answer   No answer     No answer
# 1611       No answer                      1           1     No answer
# 1612               1              No answer           1     No answer
# 1613       No answer                      1   No answer     No answer
# 1614               1              No answer   No answer     No answer
#
#      age:18 - 34 sexpref:Gay/Bisexual sexpref:Straight sexpref:Other    weight
# 0      No answer                    1        No answer     No answer  1.714026
# 1      No answer            No answer                1     No answer  1.247120
# 2      No answer            No answer                1     No answer  0.515746
# 3      No answer            No answer        No answer     No answer  0.600640
# 4      No answer            No answer                1     No answer  1.033400
# ...          ...                  ...              ...           ...       ...
# 1610           1            No answer                1     No answer  2.891038
# 1611   No answer            No answer                1     No answer  8.643674
# 1612   No answer            No answer                1     No answer  2.340241
# 1613           1            No answer                1     No answer  6.557984
# 1614           1            No answer                1     No answer  2.817560
#
# [1615 rows x 104 columns]

# %%
def normalize_columns(df):
    for i in range(len(df.columns)):
        if (df.iloc[:, i] == 1).any():
            print(f"Skipping {df.columns[i]} because it contains the value 1.")
            continue

        unique_values = df.iloc[:, i].unique()
        print(unique_values)

        if len(unique_values) == 2 and pd.isna(unique_values).sum() == 1:
            # Set the non-NaN value to 1
            non_nan_value = [value for value in unique_values if not pd.isna(value)][0]
            df[df.columns[i]] = df[df.columns[i]].replace(non_nan_value, 1)
        else:
          order = input()

          if  len(order) != len(unique_values):
            print("Invalid input: Length of order should match the number of unique values.")
            continue

            df[df.columns[i]] = df[df.columns[i]].map(mapping)
            df.loc[df.iloc[:, i] == 9, df.columns[i]] = np.nan
    return df

df = normalize_columns(df)
# Out:
# ['Somewhat masculine' 'Very masculine' 'Not at all masculine'
#  'Not very masculine' nan]
# 34129
# ['Somewhat important' 'Not too important' 'Very important'
#  'Not at all important' nan]
# 32419
# Skipping Manly ideas from Father? because it contains the value 1.
# Skipping Manly ideas from Mother? because it contains the value 1.
# Skipping Manly ideas from another member of family? because it contains the value 1.
# Skipping Manly ideas from Pop Culture? because it contains the value 1.
# Skipping Manly ideas from Friends? because it contains the value 1.
# Skipping Manly ideas from Other? because it contains the value 1.
# Skipping Does socety put pressure on men? because it contains the value 1.
# Skipping often ask friend for professional advice? because it contains the value 1.
# Skipping often ask a friend for personal advice? because it contains the value 1.
# Skipping often hug males? because it contains the value 1.
# Skipping often cry? because it contains the value 1.
# Skipping often get into physical fights? because it contains the value 1.
# Skipping often sexual with women? because it contains the value 1.
# Skipping often sexual with men? because it contains the value 1.
# Skipping often watch sports? because it contains the value 1.
# Skipping often work out? because it contains the value 1.
# Skipping often therapy? because it contains the value 1.
# Skipping often feel lonely? because it contains the value 1.
# Skipping worry:height? because it contains the value 1.
# Skipping worry:weight? because it contains the value 1.
# Skipping worry:hair? because it contains the value 1.
# Skipping worry:physique because it contains the value 1.
# Skipping worry:genitals because it contains the value 1.
# Skipping worry:clothing because it contains the value 1.
# Skipping worry:sex? because it contains the value 1.
# Skipping worry:mental health? because it contains the value 1.
# Skipping worry:physical health? because it contains the value 1.
# Skipping worry:finances? because it contains the value 1.
# Skipping worry:family because it contains the value 1.
# Skipping worry:none of above? because it contains the value 1.
# ['Yes' 'No answer']
# 19
# ['No answer' 'Yes']
# 91
# ['No answer' 'Yes']
# 91
# ['No answer' 'Yes']
# 91
# ['No answer' 'Yes']
# 91
# ['No answer' 'Yes']
# 91
# Skipping work:make more money? because it contains the value 1.
# Skipping work:taken more seriously? because it contains the value 1.
# Skipping work:have more choice? because it contains the value 1.
# Skipping work: male promotion preference because it contains the value 1.
# Skipping work:praise because it contains the value 1.
# Skipping work:manager support because it contains the value 1.
# Skipping work:other advantages because it contains the value 1.
# Skipping work:no advantages because it contains the value 1.
# Skipping work:female promotion opportunities because it contains the value 1.
# Skipping work:sexual harassment because it contains the value 1.
# Skipping work:sexist/racist accusations because it contains the value 1.
# Skipping work:other disadvantages because it contains the value 1.
# Skipping work:no disadvantages because it contains the value 1.
# Skipping harassment: confront accussed because it contains the value 1.
# Skipping harassment:contact HR because it contains the value 1.
# Skipping harassment:contact manager because it contains the value 1.
# Skipping harassment:offer victim support because it contains the value 1.
# Skipping harassment:did not respond because it contains the value 1.
# Skipping harassment:never witnessed because it contains the value 1.
# Skipping harassment: other response because it contains the value 1.
# Skipping harassment followup:You weren?t sure it was sexual harassment because it contains the value 1.
# Skipping harassment followup:You didn?t want to get involved because it contains the value 1.
# Skipping harassment followup:Other (please specify) because it contains the value 1.
# Skipping harassment followup:You didn?t think it was your place because it contains the value 1.
# Skipping harassment followup:You weren?t sure who to contact because it contains the value 1.
# [nan 'A lot' 'Only a little' 'Nothing at all' 'Some']
# 94213
# Skipping #MeToo:Changed your behaviour at work because it contains the value 1.
# Skipping Dating: First Move? because it contains the value 1.
# [3 2 'Always' 4 'Never' nan]
# 214309
# Skipping Dating: Paying is the right thing to do because it contains the value 1.
# Skipping Dating:I make more money than my date because it contains the value 1.
# Skipping Dating: Paying feels good because it contains the value 1.
# Skipping Dating:Society expects me to pay because it contains the value 1.
# Skipping Dating: I asked; I pay because it contains the value 1.
# Skipping Dating: I offer but I'm hoping they'll chip in because it contains the value 1.
# Skipping Dating: Other reason to pay because it contains the value 1.
# Skipping sex: read body language to gaugue interest because it contains the value 1.
# Skipping sex: ask for verbal consent because it contains the value 1.
# Skipping sex:make a move and see how they react because it contains the value 1.
# Skipping sex: depends on the context because it contains the value 1.
# Skipping sex:interest isnt always clear because it contains the value 1.
# Skipping sex: other way to tell because it contains the value 1.
# Skipping boundaries:wondered if you crossed them? because it contains the value 1.
# Skipping boundaries:talked to friend about pushing partner because it contains the value 1.
# Skipping boundaries:asked if you crossed them? because it contains the value 1.
# Skipping boundaries: did not wonder or ask because it contains the value 1.
# Skipping #MeeToo:Changed behaviour in relationships because it contains the value 1.
# Skipping marital status:Never married because it contains the value 1.
# Skipping marital status:Widowed because it contains the value 1.
# Skipping marital status:Married because it contains the value 1.
# Skipping marital status:Divorced because it contains the value 1.
# Skipping marital status:Separated because it contains the value 1.
# Skipping u18 children? because it contains the value 1.
# Skipping adult children because it contains the value 1.
# Skipping race:Hispanic because it contains the value 1.
# Skipping race:White because it contains the value 1.
# Skipping race:Other because it contains the value 1.
# Skipping race:Black because it contains the value 1.
# Skipping race:Asian because it contains the value 1.
# ['New York' 'Ohio' 'Michigan' 'Indiana' 'Hawaii' 'California' 'Oregon'
#  'South Carolina' 'Florida' 'Massachusetts' 'West Virginia' 'Minnesota'
#  'Kansas' 'Utah' 'Texas' 'New Jersey' 'Pennsylvania' 'Washington'
#  'South Dakota' 'Arizona' 'Idaho' 'Missouri' 'Georgia' 'Nebraska'
#  'Kentucky' 'Nevada' 'Delaware' 'Maryland' 'Virginia' 'Alabama'
#  'Tennessee' 'Montana' 'North Carolina' 'Iowa' 'Illinois' 'Vermont'
#  'Louisiana' 'Connecticut' 'Maine' 'Oklahoma' 'New Mexico' 'Mississippi'
#  'North Dakota' 'Rhode Island' 'Wisconsin' 'New Hampshire' 'Colorado'
#  'Wyoming' 'Arkansas' 'Alaska' 'District of Columbia (DC)']
#
# Invalid input: Length of order should match the number of unique values.
# ['$0-$9,999' '$50,000-$74,999' '$200,000+' '$25,000-$49,999'
#  '$150,000-$174,999' '$100,000-$124,999' '$125,000-$149,999'
#  '$10,000-$24,999' 'Prefer not to answer' '$75,000-$99,999'
#  '$175,000-$199,999' nan]
#
# Invalid input: Length of order should match the number of unique values.
# Skipping ed:College or more because it contains the value 1.
# Skipping ed:Some college because it contains the value 1.
# Skipping ed:High school or less because it contains the value 1.
# Skipping age:35 - 64 because it contains the value 1.
# Skipping age:65 and up because it contains the value 1.
# Skipping age:18 - 34 because it contains the value 1.
# Skipping sexpref:Gay/Bisexual because it contains the value 1.
# Skipping sexpref:Straight because it contains the value 1.
# Skipping sexpref:Other because it contains the value 1.
# [1.71402597 1.24712012 0.51574606 0.60064008 1.03340045 0.05908664
#  0.25735971 0.65649005 4.34185025 0.05748229 0.5007129  0.61790602
#  0.54534441 3.39834639 8.6436736  0.05814984 0.10563257 0.71690735
#  0.51240842 2.63224155 0.8699911  0.01974445 0.69561073 0.51556749
#  0.06942877 0.48454545 0.60043011 0.06903128 0.62052874 5.92864672
#  2.05030667 0.84457802 2.19324924 0.49093909 0.40820321 1.8146813
#  0.37398531 0.05403264 0.3090211  0.09910235 0.63544275 1.7015023
#  0.12588054 0.44249485 0.47062836 0.66058803 3.10591668 1.47160202
#  0.68862606 1.81611898 0.54758926 6.63205776 6.74145507 0.07642011
#  0.63941244 1.0210909  0.60725022 1.22641777 0.1043772  0.53689097
#  0.05907697 0.10690752 0.05975649 0.48173021 0.56581647 0.99202791
#  0.08791668 0.4036974  0.06069003 0.78858562 0.87954067 3.3771087
#  0.84049265 1.01004639 0.06413804 5.9546938  0.06846457 1.74382437
#  1.61594385 6.36003651 0.07689994 0.58030604 0.39741279 0.06070652
#  0.54032061 2.44823342 6.37315579 5.01849481 2.27491085 2.23794737
#  0.67683016 0.61517971 0.64445445 0.65517522 0.52119944 1.98633206
#  0.86565503 1.06555267 0.37986597 2.31604066 0.0749326  3.1201319
#  0.50449834 7.2167924  3.32295599 0.60514804 4.32042213 0.1694666
#  1.05284753 3.81759443 0.27627255 2.63895112 0.06723219 0.96130902
#  0.75976997 1.17591907 0.72424458 0.07845712 0.17450658 0.06167311
#  5.93301836 0.66335608 0.06159912 5.93009598 5.14069914 2.99663132
#  2.90345625 1.23636764 0.06000293 0.08887045 6.11309777 0.21071115
#  0.05664255 0.5379559  0.52938966 2.73195782 0.37462246 0.58294187
#  0.49628315 1.06949335 5.59089413 0.06605896 0.06087291 0.78018058
#  0.6275904  1.80631626 0.63963683 0.05724395 0.09284526 2.44831636
#  0.12282908 0.98248741 1.2658654  2.52429114 0.52911424 0.38606413
#  0.6567814  0.60899452 1.87349833 0.07667863 6.29393029 0.47667834
#  0.59333783 0.07030978 0.71305151 3.24874605 0.06426552 0.52811146
#  0.10082216 0.06970978 0.67857412 1.67958853 0.64670103 4.21335682
#  0.45288311 0.05465732 1.73689449 1.5809622  0.62074615 0.94458856
#  0.48471255 0.50053989 0.05810499 0.67294393 0.46853077 1.61720024
#  0.51269329 0.50999378 0.07338451 0.12826106 0.0598821  8.67660551
#  0.12429568 2.05551409 0.80419504 0.48395803 0.05891399 2.27333194
#  0.99917962 0.49513973 3.92379586 3.29010739 0.45410801 0.80137198
#  0.16667197 1.98749263 0.07072135 1.5178368  0.57416926 0.45249959
#  0.87032016 7.33485832 1.83665492 1.56179724 0.75462109 1.24828687
#  3.44136516 0.06998384 0.56319777 0.06628164 2.3727201  0.06259677
#  0.06165717 0.49550185 0.63057986 4.58766225 0.71028457 0.05722175
#  0.09768524 0.06537524 0.05889026 0.39215305 1.99992968 2.04970577
#  0.10928489 2.40047021 0.82512379 0.61134769 2.51791021 0.66821002
#  0.77527463 0.11719474 6.21821326 0.46735909 0.10948198 0.56064317
#  0.7924084  0.07992017 2.18832631 0.07252899 0.05614967 2.23153304
#  0.52516254 1.51987173 1.92063727 0.59354067 3.78563052 1.99920217
#  6.33964876 0.08551979 0.70399353 1.78090762 1.92947622 2.62107197
#  0.73427384 1.16510776 2.47840493 1.46974257 1.01970092 0.07089171
#  0.06641787 1.09578497 2.53254514 0.06088325 0.06618066 1.61109308
#  0.59689247 0.0684518  0.81649593 0.32798609 0.1324851  1.00721167
#  1.20882288 1.78257278 0.071511   2.36415576 2.42966814 0.55584193
#  0.80391786 0.62541377 2.72352235 0.75842582 0.59969196 2.5733245
#  0.80826112 0.94422941 0.48132034 0.05904296 1.19031759 1.61095452
#  0.07129608 1.87281758 0.05542675 4.20432286 5.28461794 0.70292737
#  0.11604714 0.71015848 0.13157865 1.73545836 0.12148749 0.78412007
#  0.1275365  0.07570292 0.19839033 0.5793327  0.5068633  1.93868421
#  0.8371719  1.70818541 0.06001294 1.80757335 1.28211296 0.1073507
#  2.73270319 0.85168021 0.31879913 0.11899076 0.05827127 2.06838014
#  0.75216066 0.63580072 1.15772667 1.21028087 0.67851743 1.79575539
#  0.13568446 0.29567019 3.04282295 0.59637743 1.27504265 0.18157594
#  0.1301386  0.34450938 0.64648046 0.46150008 0.81930618 0.19178652
#  0.49845273 3.79431872 0.1025931  0.69932323 0.07295376 1.12086155
#  0.65643531 1.76059674 0.87063903 1.75838514 4.23985657 0.75925694
#  0.56016123 3.22051608 1.13910547 2.70424744 0.70190203 1.23499056
#  0.12549573 0.07437118 1.33052458 0.61013743 0.43398117 2.38941329
#  0.20360775 2.12051414 1.66681736 0.17457266 4.44584379 0.73664171
#  0.79456854 0.75681298 0.81360532 0.07968366 0.66380036 4.21181066
#  4.26833301 0.98729112 2.0135505  0.07781769 0.89610279 1.61753925
#  0.81310534 2.48842032 1.85240753 0.45700001 1.36851453 1.81700186
#  0.17516148 1.79626359 0.57264678 0.68568331 0.71257145 0.41782403
#  0.21533173 1.08019362 1.50654088 0.09079593 0.50643047 2.53344377
#  0.10256734 1.80441769 2.50074423 1.39717483 1.56792079 0.85687808
#  1.42239259 2.45496029 2.27164526 1.82524374 0.09085158 3.46535176
#  0.65661185 0.70166162 1.04465208 0.06267451 3.23664176 1.75302929
#  4.14001128 1.48647215 1.79470867 8.34806604 0.21580256 0.13185409
#  0.57608526 0.77085382 0.97687598 0.1254615  1.17362231 1.46065456
#  1.75067698 1.86202013 0.55553144 2.93561772 0.70666089 1.57175452
#  2.44671888 2.96550791 2.9491054  0.75197949 0.81534801 2.30740524
#  0.0719358  0.8442468  0.11223403 1.20250474 0.46775619 1.19756263
#  4.13645734 0.4214939  6.40289696 1.75109923 0.11708106 0.12428818
#  1.87042442 6.1259891  3.09329259 0.77744543 1.23453992 0.54668714
#  1.85710412 1.48188896 0.83122326 0.0673582  0.89241639 1.86134822
#  0.13669341 0.12255133 7.8853891  0.12211929 0.11013963 5.05407675
#  0.75521055 1.01409707 1.75424427 0.11677305 4.3479113  1.55782454
#  0.97829771 2.66329557 0.92259435 2.40443082 0.93240258 1.04758554
#  0.91098612 1.3672948  2.56639538 1.96037559 1.95638002 4.52436584
#  1.74724145 1.49377937 2.47655617 3.0863398  0.14428522 0.85318022
#  4.71810495 0.06363035 3.25799015 0.49065256 0.64373946 0.96800162
#  1.8236069  0.73713876 0.13923132 3.81171841 3.27430542 2.36907268
#  0.23856896 1.52399061 0.77173192 1.25046848 0.11214912 4.07459943
#  2.69225861 2.80273754 0.7071357  4.68949224 1.00867909 1.51361349
#  0.07822797 1.93797935 5.18195889 4.10886756 4.69121514 1.41827922
#  0.85259097 0.15065875 2.0725818  2.69218851 0.68614333 2.21335941
#  1.40274766 0.35983644 1.46921115 2.06647235 0.09446318 1.09481431
#  0.75242677 2.2051766  1.96108874 1.58575983 4.26446499 2.48971738
#  1.63846895 1.78222006 1.13538758 2.60129686 1.39489346 0.14365033
#  1.65273615 2.8796711  1.21125434 0.98270475 5.83168868 4.23269597
#  2.34371577 2.24893148 4.56053791 0.119332   7.299153   0.23172618
#  4.8209967  2.83254278 2.59766934 5.02419376 3.19260268 4.08554454
#  1.89202647 0.53545199 1.17634197 6.53319795 4.49180666 2.61119059
#  1.11759362 1.16271932 0.09608345 1.98421761 2.89103823 2.3402406
#  6.55798384 2.81756002]
#
# Invalid input: Length of order should match the number of unique values.

# %%
df
# Out:
#      How "manly" do you feel? Is it important that people think you're manly  \
# 0          Somewhat masculine                             Somewhat important
# 1          Somewhat masculine                             Somewhat important
# 2              Very masculine                              Not too important
# 3              Very masculine                              Not too important
# 4              Very masculine                                 Very important
# ...                       ...                                            ...
# 1610       Not very masculine                           Not at all important
# 1611           Very masculine                                 Very important
# 1612       Somewhat masculine                             Somewhat important
# 1613       Somewhat masculine                             Somewhat important
# 1614           Very masculine                           Not at all important
#
#       Manly ideas from Father?  Manly ideas from Mother?  \
# 0                          NaN                       NaN
# 1                          1.0                       NaN
# 2                          1.0                       NaN
# 3                          1.0                       1.0
# 4                          NaN                       NaN
# ...                        ...                       ...
# 1610                       1.0                       1.0
# 1611                       1.0                       NaN
# 1612                       NaN                       1.0
# 1613                       NaN                       1.0
# 1614                       1.0                       1.0
#
#       Manly ideas from another member of family?  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            1.0
# 4                                            1.0
# ...                                          ...
# 1610                                         1.0
# 1611                                         1.0
# 1612                                         NaN
# 1613                                         NaN
# 1614                                         NaN
#
#       Manly ideas from Pop Culture?  Manly ideas from Friends?  \
# 0                               1.0                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 1610                            1.0                        1.0
# 1611                            NaN                        NaN
# 1612                            NaN                        NaN
# 1613                            NaN                        NaN
# 1614                            NaN                        NaN
#
#       Manly ideas from Other? Does socety put pressure on men?  \
# 0                         NaN                                1
# 1                         NaN                                1
# 2                         1.0                                0
# 3                         NaN                                0
# 4                         NaN                                1
# ...                       ...                              ...
# 1610                      NaN                                1
# 1611                      NaN                                1
# 1612                      NaN                                1
# 1613                      NaN                                1
# 1614                      NaN                                0
#
#      often ask friend for professional advice?  ... ed:College or more  \
# 0                                            4  ...                  1
# 1                                            2  ...          No answer
# 2                                            3  ...                  1
# 3                                            2  ...          No answer
# 4                                            3  ...                  1
# ...                                        ...  ...                ...
# 1610                                         2  ...          No answer
# 1611                                         4  ...          No answer
# 1612                                       NaN  ...          No answer
# 1613                                         3  ...          No answer
# 1614                                         4  ...          No answer
#
#      ed:Some college ed:High school or less age:35 - 64 age:65 and up  \
# 0          No answer              No answer           1     No answer
# 1                  1              No answer   No answer             1
# 2          No answer              No answer           1     No answer
# 3                  1              No answer   No answer             1
# 4          No answer              No answer           1     No answer
# ...              ...                    ...         ...           ...
# 1610               1              No answer   No answer     No answer
# 1611       No answer                      1           1     No answer
# 1612               1              No answer           1     No answer
# 1613       No answer                      1   No answer     No answer
# 1614               1              No answer   No answer     No answer
#
#      age:18 - 34 sexpref:Gay/Bisexual sexpref:Straight sexpref:Other    weight
# 0      No answer                    1        No answer     No answer  1.714026
# 1      No answer            No answer                1     No answer  1.247120
# 2      No answer            No answer                1     No answer  0.515746
# 3      No answer            No answer        No answer     No answer  0.600640
# 4      No answer            No answer                1     No answer  1.033400
# ...          ...                  ...              ...           ...       ...
# 1610           1            No answer                1     No answer  2.891038
# 1611   No answer            No answer                1     No answer  8.643674
# 1612   No answer            No answer                1     No answer  2.340241
# 1613           1            No answer                1     No answer  6.557984
# 1614           1            No answer                1     No answer  2.817560
#
# [1615 rows x 109 columns]

# %%
print(df.iloc[:,85:120].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   u18 children?           254 non-null    float64
#  1   adult children          875 non-null    float64
#  2   race:Hispanic           1615 non-null   object
#  3   race:White              1615 non-null   object
#  4   race:Other              1615 non-null   object
#  5   race:Black              1615 non-null   object
#  6   race:Asian              1615 non-null   object
#  7   state                   1615 non-null   object
#  8   salary                  1613 non-null   object
#  9   ed:College or more      1615 non-null   object
#  10  ed:Some college         1615 non-null   object
#  11  ed:High school or less  1615 non-null   object
#  12  age:35 - 64             1615 non-null   object
#  13  age:65 and up           1615 non-null   object
#  14  age:18 - 34             1615 non-null   object
#  15  sexpref:Gay/Bisexual    1615 non-null   object
#  16  sexpref:Straight        1615 non-null   object
#  17  sexpref:Other           1615 non-null   object
#  18  weight                  1615 non-null   float64
# dtypes: float64(3), object(16)
# memory usage: 239.9+ KB
# None
